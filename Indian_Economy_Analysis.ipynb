# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the necessary data
# ## Population

# %%
population_data = pd.read_excel("population.xls")

# %%
population_df = population_data[(population_data["Data Source"] == "India") | (population_data["Data Source"] == "Country Name")]

# %%
population_df = population_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T

# %%
population_df
# Out:
#                 2             112
# Unnamed: 4   1960.0  4.359903e+08
# Unnamed: 5   1961.0  4.465647e+08
# Unnamed: 6   1962.0  4.572831e+08
# Unnamed: 7   1963.0  4.681386e+08
# Unnamed: 8   1964.0  4.792296e+08
# ...             ...           ...
# Unnamed: 64  2020.0  1.402618e+09
# Unnamed: 65  2021.0  1.414204e+09
# Unnamed: 66  2022.0  1.425423e+09
# Unnamed: 67  2023.0  1.438070e+09
# Unnamed: 68  2024.0           NaN
#
# [65 rows x 2 columns]

# %% [markdown]
# ## Inflation

# %%
inflation_data = pd.read_excel("inflation.xls")
inflation_data
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2025-04-15 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                                 Unnamed: 2      Unnamed: 3   Unnamed: 4  \
# 0                                      NaN             NaN          NaN
# 1                                      NaN             NaN          NaN
# ...

# %%
inflation_df = inflation_data[(inflation_data["Data Source"] == "India") | (inflation_data["Data Source"] == "Country Name")]

# %%
inflation_df = inflation_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T

# %%
inflation_df
# Out:
#                 2          112
# Unnamed: 4   1960.0   1.779878
# Unnamed: 5   1961.0   1.695213
# Unnamed: 6   1962.0   3.632215
# Unnamed: 7   1963.0   2.946161
# Unnamed: 8   1964.0  13.355261
# ...             ...        ...
# Unnamed: 64  2020.0   6.623437
# Unnamed: 65  2021.0   5.131407
# Unnamed: 66  2022.0   6.699034
# Unnamed: 67  2023.0   5.649143
# Unnamed: 68  2024.0   4.953036
#
# [65 rows x 2 columns]

# %% [markdown]
# ## Fiscal Data

# %%
fiscal_data = pd.read_excel("imf-dm-export-20250526.xls")

# %%
fiscal_df = fiscal_data[(fiscal_data["Net lending/borrowing (also referred as overall balance) (% of GDP)"] == "India")]

# %%
fiscal_df
# Out:
#   Net lending/borrowing (also referred as overall balance) (% of GDP)  \
# 1                                              India
#
#        1990      1991      1992      1993      1994      1995      1996  \
# 1 -8.068605 -7.900177 -7.893089 -8.570185 -7.996919 -6.814407 -6.705176
#
#      1997      1998  ...      2021     2022      2023      2024      2025  \
# 1 -8.2761 -9.742369  ... -9.447939 -8.96884 -7.916037 -7.377034 -6.858133
#
#        2026      2027      2028      2029     2030
# 1 -7.157252 -7.072793 -6.988266 -6.808375 -6.65025
#
# [1 rows x 42 columns]

# %%
fiscal_df = fiscal_df.iloc[:, 1:-6].T
fiscal_df
# Out:
#               1
# 1990  -8.068605
# 1991  -7.900177
# 1992  -7.893089
# 1993  -8.570185
# 1994  -7.996919
# 1995  -6.814407
# 1996  -6.705176
# 1997  -8.276100
# 1998  -9.742369
# 1999  -8.700689
# 2000  -8.408912
# 2001 -11.032990
# 2002 -11.072106
# 2003 -11.428096
# 2004  -9.221002
# 2005  -7.492563
# 2006  -6.380250
# 2007  -4.586463
# 2008  -9.170982
# 2009  -9.700886
# 2010  -8.794928
# 2011  -8.349152
# 2012  -7.549560
# 2013  -6.999618
# 2014  -7.071069
# 2015  -7.205084
# 2016  -7.120010
# 2017  -6.227236
# 2018  -6.375815
# 2019  -7.694073
# 2020 -12.864419
# 2021  -9.447939
# 2022  -8.968840
# 2023  -7.916037
# 2024  -7.377034

# %% [markdown]
# ## GDP Growth Rate

# %%
gdp_gr = pd.read_excel("gdp_growth_rate.xls")
gdp_gr
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2025-04-15 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                 Unnamed: 2         Unnamed: 3  Unnamed: 4   Unnamed: 5  \
# 0                      NaN                NaN         NaN          NaN
# 1                      NaN                NaN         NaN          NaN
# ...

# %%
gdp_growth_rate_df = gdp_gr[(gdp_gr["Data Source"] == "India") | (gdp_gr["Data Source"] == "Country Name")]
gdp_growth_rate_df
# Out:
#       Data Source World Development Indicators             Unnamed: 2  \
# 2    Country Name                 Country Code         Indicator Name
# 112         India                          IND  GDP growth (annual %)
#
#             Unnamed: 3  Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7  \
# 2       Indicator Code      1960.0  1961.000000  1962.000000  1963.000000
# 112  NY.GDP.MKTP.KD.ZG         NaN     3.722743     2.931128     5.994353
#
#      Unnamed: 8  Unnamed: 9  ...  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# 2    1964.00000  1965.00000  ...  2015.000000  2016.000000  2017.000000
# 112     7.45295    -2.63577  ...     7.996254     8.256306     6.795383
#
#      Unnamed: 62  Unnamed: 63  Unnamed: 64  Unnamed: 65  Unnamed: 66  \
# 2    2018.000000  2019.000000  2020.000000  2021.000000  2022.000000
# 112     6.453851     3.871437    -5.777725     9.689592     6.987039
#
#      Unnamed: 67  Unnamed: 68
# 2    2023.000000       2024.0
# 112     8.152936          NaN
#
# ...

# %%
gdp_growth_rate_df = gdp_growth_rate_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
gdp_growth_rate_df
# Out:
#                 2         112
# Unnamed: 4   1960.0       NaN
# Unnamed: 5   1961.0  3.722743
# Unnamed: 6   1962.0  2.931128
# Unnamed: 7   1963.0  5.994353
# Unnamed: 8   1964.0  7.452950
# ...             ...       ...
# Unnamed: 64  2020.0 -5.777725
# Unnamed: 65  2021.0  9.689592
# Unnamed: 66  2022.0  6.987039
# Unnamed: 67  2023.0  8.152936
# Unnamed: 68  2024.0       NaN
#
# [65 rows x 2 columns]

# %% [markdown]
# ## Exchange Rates

# %%
exchange_rates_data = pd.read_excel("exchange_rates.xls")

# %%
exchange_rates_data
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2025-04-15 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                                             Unnamed: 2      Unnamed: 3  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# ...

# %%
exchange_rates_df = exchange_rates_data[(exchange_rates_data["Data Source"] == "India") | (exchange_rates_data["Data Source"] == "Country Name")]

# %%
exchange_rates_df = exchange_rates_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T

# %%
exchange_rates_df
# Out:
#                 2          112
# Unnamed: 4   1960.0   4.761900
# Unnamed: 5   1961.0   4.761900
# Unnamed: 6   1962.0   4.761900
# Unnamed: 7   1963.0   4.761900
# Unnamed: 8   1964.0   4.761900
# ...             ...        ...
# Unnamed: 64  2020.0  74.099567
# Unnamed: 65  2021.0  73.918013
# Unnamed: 66  2022.0  78.604491
# Unnamed: 67  2023.0  82.599276
# Unnamed: 68  2024.0  83.669282
#
# [65 rows x 2 columns]

# %% [markdown]
# ## Unemployment Data

# %%
unemployment_data = pd.read_excel("unemployment.xls")

# %%
unemployment_data
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2025-04-15 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                                             Unnamed: 2      Unnamed: 3  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# ...

# %%
unemployment_df = unemployment_data[(unemployment_data["Data Source"] == "India") | (unemployment_data["Data Source"] == "Country Name")]

# %%
unemployment_df = unemployment_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
unemployment_df
# Out:
#                 2      112
# Unnamed: 4   1960.0    NaN
# Unnamed: 5   1961.0    NaN
# Unnamed: 6   1962.0    NaN
# Unnamed: 7   1963.0    NaN
# Unnamed: 8   1964.0    NaN
# ...             ...    ...
# Unnamed: 64  2020.0  7.859
# Unnamed: 65  2021.0  6.380
# Unnamed: 66  2022.0  4.822
# Unnamed: 67  2023.0  4.172
# Unnamed: 68  2024.0  4.202
#
# [65 rows x 2 columns]

# %% [markdown]
# ## GDP

# %%
gdp_data = pd.read_excel("gdp.xls")

# %%
gdp_data
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2025-04-15 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                        Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# 0                             NaN             NaN          NaN          NaN
# ...

# %%
gdp_df = gdp_data[(gdp_data["Data Source"] == "India") | (gdp_data["Data Source"] == "Country Name")]

# %%
gdp_df = gdp_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
gdp_df
# Out:
#                 2            112
# Unnamed: 4   1960.0    84.932808
# Unnamed: 5   1961.0    87.853861
# Unnamed: 6   1962.0    92.199958
# Unnamed: 7   1963.0   103.435021
# Unnamed: 8   1964.0   117.856431
# ...             ...          ...
# Unnamed: 64  2020.0  1907.042516
# Unnamed: 65  2021.0  2239.613844
# Unnamed: 66  2022.0  2352.613925
# Unnamed: 67  2023.0  2480.792087
# Unnamed: 68  2024.0          NaN
#
# [65 rows x 2 columns]

# %% [markdown]
# ## Current Account Balance

# %%
current_acc_balance_data = pd.read_excel("current_account_balance.xls")

# %%
current_acc_balance_df = current_acc_balance_data[(current_acc_balance_data["Data Source"] == "India") | (current_acc_balance_data["Data Source"] == "Country Name")]

# %%
current_acc_balance_df = current_acc_balance_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
current_acc_balance_df
# Out:
#                 2         112
# Unnamed: 4   1960.0       NaN
# Unnamed: 5   1961.0       NaN
# Unnamed: 6   1962.0       NaN
# Unnamed: 7   1963.0       NaN
# Unnamed: 8   1964.0       NaN
# ...             ...       ...
# Unnamed: 64  2020.0  1.223621
# Unnamed: 65  2021.0 -1.055242
# Unnamed: 66  2022.0 -2.357288
# Unnamed: 67  2023.0 -0.895917
# Unnamed: 68  2024.0       NaN
#
# [65 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## External Balance Of Goods And Services

# %%
external_balance_of_goods_and_services_data = pd.read_excel("external_balance_of_goods_and_services.xls")

# %%
external_balance_of_goods_and_services_df = external_balance_of_goods_and_services_data[(external_balance_of_goods_and_services_data["Data Source"] == "India") | (external_balance_of_goods_and_services_data["Data Source"] == "Country Name")]
external_balance_of_goods_and_services_df
# Out:
#       Data Source World Development Indicators  \
# 2    Country Name                 Country Code
# 112         India                          IND
#
#                                             Unnamed: 2      Unnamed: 3  \
# 2                                       Indicator Name  Indicator Code
# 112  External balance on goods and services (% of GDP)  NE.RSB.GNFS.ZS
#
#      Unnamed: 4  Unnamed: 5  Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 2    1960.00000  1961.00000  1962.00000  1963.000000  1964.000000
# 112    -2.37052    -1.65399    -1.86284    -1.626331    -1.959447
#
#       Unnamed: 9  ...  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  \
# 2    1965.000000  ...  2015.000000  2016.000000  2017.000000  2018.000000
# 112    -1.904089  ...    -2.296536    -1.766016    -3.158967    -3.761312
#
#      Unnamed: 63  Unnamed: 64  Unnamed: 65  Unnamed: 66  Unnamed: 67  \
# 2    2019.000000  2020.000000  2021.000000  2022.000000  2023.000000
# ...

# %%
external_balance_of_goods_and_services_df = external_balance_of_goods_and_services_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
external_balance_of_goods_and_services_df
# Out:
#                 2         112
# Unnamed: 4   1960.0 -2.370520
# Unnamed: 5   1961.0 -1.653990
# Unnamed: 6   1962.0 -1.862840
# Unnamed: 7   1963.0 -1.626331
# Unnamed: 8   1964.0 -1.959447
# Unnamed: 9   1965.0 -1.904089
# Unnamed: 10  1966.0 -2.529136
# Unnamed: 11  1967.0 -1.912173
# Unnamed: 12  1968.0 -0.904202
# Unnamed: 13  1969.0 -0.317091
# Unnamed: 14  1970.0 -0.096119
# Unnamed: 15  1971.0 -0.335196
# Unnamed: 16  1972.0  0.318579
# Unnamed: 17  1973.0 -0.514570
# Unnamed: 18  1974.0 -1.189248
# Unnamed: 19  1975.0 -0.999854
# Unnamed: 20  1976.0  0.571823
# Unnamed: 21  1977.0  0.118242
# Unnamed: 22  1978.0 -0.273361
# Unnamed: 23  1979.0 -1.419528
# Unnamed: 24  1980.0 -3.105475
# Unnamed: 25  1981.0 -2.635212
# Unnamed: 26  1982.0 -2.159328
# Unnamed: 27  1983.0 -2.015335
# Unnamed: 28  1984.0 -1.442573
# Unnamed: 29  1985.0 -2.390926
# Unnamed: 30  1986.0 -1.826829
# Unnamed: 31  1987.0 -1.375652
# Unnamed: 32  1988.0 -1.420011
# Unnamed: 33  1989.0 -1.135872
# ...

# %% [markdown]
# ## Foreign Direct Investment Inflows

# %%
fdi_inflows_data = pd.read_excel("fdi_inflows.xls")

# %%
fdi_inflows_df = fdi_inflows_data[(fdi_inflows_data["Data Source"] == "India") | (fdi_inflows_data["Data Source"] == "Country Name")]

# %%
fdi_inflows_df = fdi_inflows_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
fdi_inflows_df
# Out:
#                 2         112
# Unnamed: 4   1960.0       NaN
# Unnamed: 5   1961.0       NaN
# Unnamed: 6   1962.0       NaN
# Unnamed: 7   1963.0       NaN
# Unnamed: 8   1964.0       NaN
# Unnamed: 9   1965.0       NaN
# Unnamed: 10  1966.0       NaN
# Unnamed: 11  1967.0       NaN
# Unnamed: 12  1968.0       NaN
# Unnamed: 13  1969.0       NaN
# Unnamed: 14  1970.0  0.072826
# Unnamed: 15  1971.0  0.070763
# Unnamed: 16  1972.0  0.024893
# Unnamed: 17  1973.0  0.044330
# Unnamed: 18  1974.0  0.057241
# Unnamed: 19  1975.0 -0.010486
# Unnamed: 20  1976.0 -0.007503
# Unnamed: 21  1977.0 -0.029682
# Unnamed: 22  1978.0  0.013175
# Unnamed: 23  1979.0  0.031746
# Unnamed: 24  1980.0  0.042484
# Unnamed: 25  1981.0  0.047506
# Unnamed: 26  1982.0  0.035912
# Unnamed: 27  1983.0  0.002584
# Unnamed: 28  1984.0  0.009069
# Unnamed: 29  1985.0  0.045628
# Unnamed: 30  1986.0  0.047284
# Unnamed: 31  1987.0  0.076091
# Unnamed: 32  1988.0  0.030766
# Unnamed: 33  1989.0  0.085157
# ...

# %% [markdown]
# ## Foreign Direct Investment Outflows

# %%
fdi_outflows_data = pd.read_excel("fdi_outflows.xls")

# %%
fdi_outflows_df = fdi_outflows_data[(fdi_outflows_data["Data Source"] == "India") | (fdi_outflows_data["Data Source"] == "Country Name")]

# %%
fdi_outflows_df = fdi_outflows_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
fdi_outflows_df
# Out:
#                 2         112
# Unnamed: 4   1960.0       NaN
# Unnamed: 5   1961.0       NaN
# Unnamed: 6   1962.0       NaN
# Unnamed: 7   1963.0       NaN
# Unnamed: 8   1964.0       NaN
# Unnamed: 9   1965.0       NaN
# Unnamed: 10  1966.0       NaN
# Unnamed: 11  1967.0       NaN
# Unnamed: 12  1968.0       NaN
# Unnamed: 13  1969.0       NaN
# Unnamed: 14  1970.0       NaN
# Unnamed: 15  1971.0       NaN
# Unnamed: 16  1972.0       NaN
# Unnamed: 17  1973.0       NaN
# Unnamed: 18  1974.0       NaN
# Unnamed: 19  1975.0  0.000000
# Unnamed: 20  1976.0  0.000000
# Unnamed: 21  1977.0  0.000000
# Unnamed: 22  1978.0  0.000000
# Unnamed: 23  1979.0  0.000000
# Unnamed: 24  1980.0  0.002147
# Unnamed: 25  1981.0  0.001034
# Unnamed: 26  1982.0  0.000498
# Unnamed: 27  1983.0  0.002291
# Unnamed: 28  1984.0  0.001885
# Unnamed: 29  1985.0  0.001290
# Unnamed: 30  1986.0 -0.000402
# Unnamed: 31  1987.0  0.001792
# Unnamed: 32  1988.0  0.003709
# Unnamed: 33  1989.0  0.003378
# ...

# %% [markdown]
# ## Government Debt

# %%
gov_debt_data = pd.read_excel("gov_debt.xls")

# %%
gov_debt_df = gov_debt_data[(gov_debt_data["Data Source"] == "India") | (gov_debt_data["Data Source"] == "Country Name")]

# %%
gov_debt_df = gov_debt_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
gov_debt_df
# Out:
#                 2          112
# Unnamed: 4   1960.0        NaN
# Unnamed: 5   1961.0        NaN
# Unnamed: 6   1962.0        NaN
# Unnamed: 7   1963.0        NaN
# Unnamed: 8   1964.0        NaN
# Unnamed: 9   1965.0        NaN
# Unnamed: 10  1966.0        NaN
# Unnamed: 11  1967.0        NaN
# Unnamed: 12  1968.0        NaN
# Unnamed: 13  1969.0        NaN
# Unnamed: 14  1970.0        NaN
# Unnamed: 15  1971.0        NaN
# Unnamed: 16  1972.0        NaN
# Unnamed: 17  1973.0        NaN
# Unnamed: 18  1974.0        NaN
# Unnamed: 19  1975.0        NaN
# Unnamed: 20  1976.0        NaN
# Unnamed: 21  1977.0        NaN
# Unnamed: 22  1978.0        NaN
# Unnamed: 23  1979.0        NaN
# Unnamed: 24  1980.0        NaN
# Unnamed: 25  1981.0        NaN
# Unnamed: 26  1982.0        NaN
# Unnamed: 27  1983.0        NaN
# Unnamed: 28  1984.0        NaN
# Unnamed: 29  1985.0        NaN
# Unnamed: 30  1986.0        NaN
# Unnamed: 31  1987.0        NaN
# Unnamed: 32  1988.0        NaN
# ...

# %% [markdown]
# ## Lobour Force Participation

# %%
labour_force_participation = pd.read_excel("labour_force_participation.xls")

# %%
labour_force_participation_df = labour_force_participation[(labour_force_participation["Data Source"] == "India") | (labour_force_participation["Data Source"] == "Country Name")]

# %%
labour_force_participation_df = labour_force_participation_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
labour_force_participation_df
# Out:
#                 2       112
# Unnamed: 4   1960.0     NaN
# Unnamed: 5   1961.0     NaN
# Unnamed: 6   1962.0     NaN
# Unnamed: 7   1963.0     NaN
# Unnamed: 8   1964.0     NaN
# Unnamed: 9   1965.0     NaN
# Unnamed: 10  1966.0     NaN
# Unnamed: 11  1967.0     NaN
# Unnamed: 12  1968.0     NaN
# Unnamed: 13  1969.0     NaN
# Unnamed: 14  1970.0     NaN
# Unnamed: 15  1971.0     NaN
# Unnamed: 16  1972.0     NaN
# Unnamed: 17  1973.0     NaN
# Unnamed: 18  1974.0     NaN
# Unnamed: 19  1975.0     NaN
# Unnamed: 20  1976.0     NaN
# Unnamed: 21  1977.0     NaN
# Unnamed: 22  1978.0     NaN
# Unnamed: 23  1979.0     NaN
# Unnamed: 24  1980.0     NaN
# Unnamed: 25  1981.0     NaN
# Unnamed: 26  1982.0     NaN
# Unnamed: 27  1983.0     NaN
# Unnamed: 28  1984.0     NaN
# Unnamed: 29  1985.0     NaN
# Unnamed: 30  1986.0     NaN
# Unnamed: 31  1987.0     NaN
# Unnamed: 32  1988.0     NaN
# Unnamed: 33  1989.0     NaN
# Unnamed: 34  1990.0  59.868
# Unnamed: 35  1991.0  59.919
# ...

# %% [markdown]
# ## Lending Interest

# %%
lending_interest = pd.read_excel("lending_interest.xls")

# %%
lending_interest_df = lending_interest[(lending_interest["Data Source"] == "India") | (lending_interest["Data Source"] == "Country Name")]

# %%
lending_interest_df = lending_interest_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
lending_interest_df
# Out:
#                 2          112
# Unnamed: 4   1960.0        NaN
# Unnamed: 5   1961.0        NaN
# Unnamed: 6   1962.0        NaN
# Unnamed: 7   1963.0        NaN
# Unnamed: 8   1964.0        NaN
# Unnamed: 9   1965.0        NaN
# Unnamed: 10  1966.0        NaN
# Unnamed: 11  1967.0        NaN
# Unnamed: 12  1968.0        NaN
# Unnamed: 13  1969.0        NaN
# Unnamed: 14  1970.0        NaN
# Unnamed: 15  1971.0        NaN
# Unnamed: 16  1972.0        NaN
# Unnamed: 17  1973.0        NaN
# Unnamed: 18  1974.0        NaN
# Unnamed: 19  1975.0        NaN
# Unnamed: 20  1976.0        NaN
# Unnamed: 21  1977.0        NaN
# Unnamed: 22  1978.0  13.500000
# Unnamed: 23  1979.0  14.500000
# Unnamed: 24  1980.0  16.500000
# Unnamed: 25  1981.0  16.500000
# Unnamed: 26  1982.0  16.500000
# Unnamed: 27  1983.0  16.500000
# Unnamed: 28  1984.0  16.500000
# Unnamed: 29  1985.0  16.500000
# Unnamed: 30  1986.0  16.500000
# Unnamed: 31  1987.0  16.500000
# Unnamed: 32  1988.0  16.500000
# ...

# %% [markdown]
# ## Life Expectancy

# %%
life_expectancy = pd.read_excel("life_expectancy.xls")

# %%
life_expectancy_df = life_expectancy[(life_expectancy["Data Source"] == "India") | (life_expectancy["Data Source"] == "Country Name")]

# %%
life_expectancy_df = life_expectancy_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
life_expectancy_df
# Out:
#                 2       112
# Unnamed: 4   1960.0  45.610
# Unnamed: 5   1961.0  45.824
# Unnamed: 6   1962.0  46.133
# Unnamed: 7   1963.0  46.458
# Unnamed: 8   1964.0  46.742
# Unnamed: 9   1965.0  45.558
# Unnamed: 10  1966.0  45.884
# Unnamed: 11  1967.0  46.184
# Unnamed: 12  1968.0  47.925
# Unnamed: 13  1969.0  48.260
# Unnamed: 14  1970.0  48.585
# Unnamed: 15  1971.0  48.902
# Unnamed: 16  1972.0  49.213
# Unnamed: 17  1973.0  49.642
# Unnamed: 18  1974.0  50.259
# Unnamed: 19  1975.0  50.761
# Unnamed: 20  1976.0  51.302
# Unnamed: 21  1977.0  51.822
# Unnamed: 22  1978.0  52.420
# Unnamed: 23  1979.0  53.014
# Unnamed: 24  1980.0  53.593
# Unnamed: 25  1981.0  54.173
# Unnamed: 26  1982.0  54.735
# Unnamed: 27  1983.0  55.283
# Unnamed: 28  1984.0  55.813
# Unnamed: 29  1985.0  56.324
# Unnamed: 30  1986.0  56.819
# Unnamed: 31  1987.0  57.291
# Unnamed: 32  1988.0  57.744
# Unnamed: 33  1989.0  58.196
# Unnamed: 34  1990.0  58.618
# Unnamed: 35  1991.0  59.032
# ...

# %% [markdown]
# ## Personal Remittance

# %%
personal_remittance = pd.read_excel("personal_remittance.xls")

# %%
personal_remittance_df = personal_remittance[(personal_remittance["Data Source"] == "India") | (personal_remittance["Data Source"] == "Country Name")]

# %%
personal_remittance_df = personal_remittance_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
personal_remittance_df
# Out:
#                 2         112
# Unnamed: 4   1960.0       NaN
# Unnamed: 5   1961.0       NaN
# Unnamed: 6   1962.0       NaN
# Unnamed: 7   1963.0       NaN
# Unnamed: 8   1964.0       NaN
# Unnamed: 9   1965.0       NaN
# Unnamed: 10  1966.0       NaN
# Unnamed: 11  1967.0       NaN
# Unnamed: 12  1968.0       NaN
# Unnamed: 13  1969.0       NaN
# Unnamed: 14  1970.0       NaN
# Unnamed: 15  1971.0       NaN
# Unnamed: 16  1972.0       NaN
# Unnamed: 17  1973.0       NaN
# Unnamed: 18  1974.0       NaN
# Unnamed: 19  1975.0  0.436546
# Unnamed: 20  1976.0  0.625356
# Unnamed: 21  1977.0  0.769151
# Unnamed: 22  1978.0  0.848330
# Unnamed: 23  1979.0  0.939256
# Unnamed: 24  1980.0  1.479631
# Unnamed: 25  1981.0  1.189415
# Unnamed: 26  1982.0  1.304169
# Unnamed: 27  1983.0  1.218755
# Unnamed: 28  1984.0  1.081625
# Unnamed: 29  1985.0  1.061973
# Unnamed: 30  1986.0  0.899610
# Unnamed: 31  1987.0  0.955231
# Unnamed: 32  1988.0  0.780640
# Unnamed: 33  1989.0  0.882930
# ...

# %% [markdown]
# ## Trade Balance

# %%
trade_balance = pd.read_excel("trade_balance.xls")

# %%
trade_balance_df = trade_balance[(trade_balance["Data Source"] == "India") | (trade_balance["Data Source"] == "Country Name")]

# %%
trade_balance_df = trade_balance_df.loc[:, "Unnamed: 4":"Unnamed: 68"].T
trade_balance_df
# Out:
#                 2         112
# Unnamed: 4   1960.0 -2.370520
# Unnamed: 5   1961.0 -1.653990
# Unnamed: 6   1962.0 -1.862840
# Unnamed: 7   1963.0 -1.626331
# Unnamed: 8   1964.0 -1.959447
# Unnamed: 9   1965.0 -1.904089
# Unnamed: 10  1966.0 -2.529136
# Unnamed: 11  1967.0 -1.912173
# Unnamed: 12  1968.0 -0.904202
# Unnamed: 13  1969.0 -0.317091
# Unnamed: 14  1970.0 -0.096119
# Unnamed: 15  1971.0 -0.335196
# Unnamed: 16  1972.0  0.318579
# Unnamed: 17  1973.0 -0.514570
# Unnamed: 18  1974.0 -1.189248
# Unnamed: 19  1975.0 -0.999854
# Unnamed: 20  1976.0  0.571823
# Unnamed: 21  1977.0  0.118242
# Unnamed: 22  1978.0 -0.273361
# Unnamed: 23  1979.0 -1.419528
# Unnamed: 24  1980.0 -3.105475
# Unnamed: 25  1981.0 -2.635212
# Unnamed: 26  1982.0 -2.159328
# Unnamed: 27  1983.0 -2.015335
# Unnamed: 28  1984.0 -1.442573
# Unnamed: 29  1985.0 -2.390926
# Unnamed: 30  1986.0 -1.826829
# Unnamed: 31  1987.0 -1.375652
# Unnamed: 32  1988.0 -1.420011
# Unnamed: 33  1989.0 -1.135872
# ...

# %% [markdown]
# # Collate the data into a single table

# %%
df = pd.concat([population_df, inflation_df, gdp_df, gdp_growth_rate_df, unemployment_df, life_expectancy_df, trade_balance_df, personal_remittance_df, lending_interest_df, gov_debt_df, fdi_inflows_df, fdi_outflows_df, labour_force_participation_df, external_balance_of_goods_and_services_df, current_acc_balance_df, exchange_rates_df], axis = 1)

# %%
df
# Out:
#                 2             112     2          112     2            112  \
# Unnamed: 4   1960.0  4.359903e+08  1960.0   1.779878  1960.0    84.932808
# Unnamed: 5   1961.0  4.465647e+08  1961.0   1.695213  1961.0    87.853861
# Unnamed: 6   1962.0  4.572831e+08  1962.0   3.632215  1962.0    92.199958
# Unnamed: 7   1963.0  4.681386e+08  1963.0   2.946161  1963.0   103.435021
# Unnamed: 8   1964.0  4.792296e+08  1964.0  13.355261  1964.0   117.856431
# Unnamed: 9   1965.0  4.901401e+08  1965.0   9.474759  1965.0   121.508319
# Unnamed: 10  1966.0  5.007402e+08  1966.0  10.801848  1966.0    91.027695
# Unnamed: 11  1967.0  5.116064e+08  1967.0  13.062202  1967.0    97.995148
# Unnamed: 12  1968.0  5.227169e+08  1968.0   3.237412  1968.0   101.556803
# Unnamed: 13  1969.0  5.338805e+08  1969.0  -0.584137  1969.0   109.477664
# Unnamed: 14  1970.0  5.458643e+08  1970.0   5.092262  1970.0   114.355320
# Unnamed: 15  1971.0  5.580964e+08  1971.0   3.079939  1971.0   120.680596
# ...

# %%
df.index = list(range(1960, 2025))

# %%
df
# Out:
#          2             112     2          112     2            112     2    \
# 1960  1960.0  4.359903e+08  1960.0   1.779878  1960.0    84.932808  1960.0
# 1961  1961.0  4.465647e+08  1961.0   1.695213  1961.0    87.853861  1961.0
# 1962  1962.0  4.572831e+08  1962.0   3.632215  1962.0    92.199958  1962.0
# 1963  1963.0  4.681386e+08  1963.0   2.946161  1963.0   103.435021  1963.0
# 1964  1964.0  4.792296e+08  1964.0  13.355261  1964.0   117.856431  1964.0
# 1965  1965.0  4.901401e+08  1965.0   9.474759  1965.0   121.508319  1965.0
# 1966  1966.0  5.007402e+08  1966.0  10.801848  1966.0    91.027695  1966.0
# 1967  1967.0  5.116064e+08  1967.0  13.062202  1967.0    97.995148  1967.0
# 1968  1968.0  5.227169e+08  1968.0   3.237412  1968.0   101.556803  1968.0
# 1969  1969.0  5.338805e+08  1969.0  -0.584137  1969.0   109.477664  1969.0
# 1970  1970.0  5.458643e+08  1970.0   5.092262  1970.0   114.355320  1970.0
# ...

# %%
df = pd.concat([df, fiscal_df], axis = 1)

# %%
df
# Out:
#          2             112     2          112     2            112     2    \
# 1960  1960.0  4.359903e+08  1960.0   1.779878  1960.0    84.932808  1960.0
# 1961  1961.0  4.465647e+08  1961.0   1.695213  1961.0    87.853861  1961.0
# 1962  1962.0  4.572831e+08  1962.0   3.632215  1962.0    92.199958  1962.0
# 1963  1963.0  4.681386e+08  1963.0   2.946161  1963.0   103.435021  1963.0
# 1964  1964.0  4.792296e+08  1964.0  13.355261  1964.0   117.856431  1964.0
# 1965  1965.0  4.901401e+08  1965.0   9.474759  1965.0   121.508319  1965.0
# 1966  1966.0  5.007402e+08  1966.0  10.801848  1966.0    91.027695  1966.0
# 1967  1967.0  5.116064e+08  1967.0  13.062202  1967.0    97.995148  1967.0
# 1968  1968.0  5.227169e+08  1968.0   3.237412  1968.0   101.556803  1968.0
# 1969  1969.0  5.338805e+08  1969.0  -0.584137  1969.0   109.477664  1969.0
# 1970  1970.0  5.458643e+08  1970.0   5.092262  1970.0   114.355320  1970.0
# ...

# %%
df.drop(columns = [2], inplace = True)

# %%
df
# Out:
#                112        112          112       112    112     112       112  \
# 1960  4.359903e+08   1.779878    84.932808       NaN    NaN  45.610 -2.370520
# 1961  4.465647e+08   1.695213    87.853861  3.722743    NaN  45.824 -1.653990
# 1962  4.572831e+08   3.632215    92.199958  2.931128    NaN  46.133 -1.862840
# 1963  4.681386e+08   2.946161   103.435021  5.994353    NaN  46.458 -1.626331
# 1964  4.792296e+08  13.355261   117.856431  7.452950    NaN  46.742 -1.959447
# 1965  4.901401e+08   9.474759   121.508319 -2.635770    NaN  45.558 -1.904089
# 1966  5.007402e+08  10.801848    91.027695 -0.055329    NaN  45.884 -2.529136
# 1967  5.116064e+08  13.062202    97.995148  7.825963    NaN  46.184 -1.912173
# 1968  5.227169e+08   3.237412   101.556803  3.387929    NaN  47.925 -0.904202
# 1969  5.338805e+08  -0.584137   109.477664  6.539700    NaN  48.260 -0.317091
# 1970  5.458643e+08   5.092262   114.355320  5.157230    NaN  48.585 -0.096119
# ...

# %%
df.columns = [
    'population', 'inflation', 'gdp_per_capita', 'gdp_growth_rate', 'unemployment', 'life_expectancy', 
    'trade_balance', 'personal_remittance', 'lending_interest', 'gov_debt', 
    'fdi_inflows', 'fdi_outflows', 'labour_force_participation', 
    'external_balance_of_goods_and_services',
    'current_acc_balance', 'exchange_rates', 'fiscal_data'
]

# %%
df
# Out:
#         population  inflation  gdp_per_capita  gdp_growth_rate  unemployment  \
# 1960  4.359903e+08   1.779878       84.932808              NaN           NaN
# 1961  4.465647e+08   1.695213       87.853861         3.722743           NaN
# 1962  4.572831e+08   3.632215       92.199958         2.931128           NaN
# 1963  4.681386e+08   2.946161      103.435021         5.994353           NaN
# 1964  4.792296e+08  13.355261      117.856431         7.452950           NaN
# 1965  4.901401e+08   9.474759      121.508319        -2.635770           NaN
# 1966  5.007402e+08  10.801848       91.027695        -0.055329           NaN
# 1967  5.116064e+08  13.062202       97.995148         7.825963           NaN
# 1968  5.227169e+08   3.237412      101.556803         3.387929           NaN
# 1969  5.338805e+08  -0.584137      109.477664         6.539700           NaN
# 1970  5.458643e+08   5.092262      114.355320         5.157230           NaN
# ...

# %%
# More data collected from Wikipedia
df.loc[2019:2024, "gov_debt"] = [49.300, 61.000, 57.400, 56.500, 57.100, 56.300]

# %%
df
# Out:
#         population  inflation  gdp_per_capita  gdp_growth_rate  unemployment  \
# 1960  4.359903e+08   1.779878       84.932808              NaN           NaN
# 1961  4.465647e+08   1.695213       87.853861         3.722743           NaN
# 1962  4.572831e+08   3.632215       92.199958         2.931128           NaN
# 1963  4.681386e+08   2.946161      103.435021         5.994353           NaN
# 1964  4.792296e+08  13.355261      117.856431         7.452950           NaN
# 1965  4.901401e+08   9.474759      121.508319        -2.635770           NaN
# 1966  5.007402e+08  10.801848       91.027695        -0.055329           NaN
# 1967  5.116064e+08  13.062202       97.995148         7.825963           NaN
# 1968  5.227169e+08   3.237412      101.556803         3.387929           NaN
# 1969  5.338805e+08  -0.584137      109.477664         6.539700           NaN
# 1970  5.458643e+08   5.092262      114.355320         5.157230           NaN
# ...

# %%
# According to trending economics the lending interest for 2023 and 2024 was 9.7225 and 9.88666 resp.
df.loc[2023:2024, "lending_interest"] = [9.722500, 9.886666]

# %%
df
# Out:
#         population  inflation  gdp_per_capita  gdp_growth_rate  unemployment  \
# 1960  4.359903e+08   1.779878       84.932808              NaN           NaN
# 1961  4.465647e+08   1.695213       87.853861         3.722743           NaN
# 1962  4.572831e+08   3.632215       92.199958         2.931128           NaN
# 1963  4.681386e+08   2.946161      103.435021         5.994353           NaN
# 1964  4.792296e+08  13.355261      117.856431         7.452950           NaN
# 1965  4.901401e+08   9.474759      121.508319        -2.635770           NaN
# 1966  5.007402e+08  10.801848       91.027695        -0.055329           NaN
# 1967  5.116064e+08  13.062202       97.995148         7.825963           NaN
# 1968  5.227169e+08   3.237412      101.556803         3.387929           NaN
# 1969  5.338805e+08  -0.584137      109.477664         6.539700           NaN
# 1970  5.458643e+08   5.092262      114.355320         5.157230           NaN
# ...

# %%
df.dropna(axis = 0, inplace = True)

# %%
df
# Out:
#         population  inflation  gdp_per_capita  gdp_growth_rate  unemployment  \
# 1991  8.839276e+08  13.870246      305.574056         1.056831         7.722
# 1992  9.029571e+08  11.787817      319.182473         5.482396         7.733
# 1993  9.221184e+08   6.326890      302.884806         4.750776         7.750
# 1994  9.411638e+08  10.247936      347.734215         6.658924         7.645
# 1995  9.603010e+08  10.224886      375.176005         7.574492         7.608
# 1996  9.796785e+08   8.977152      401.046755         7.549522         7.558
# 1997  9.991338e+08   7.164252      416.228116         4.049821         7.610
# 1998  1.018665e+09  13.230839      413.630864         6.184416         7.639
# 1999  1.038226e+09   4.669820      441.927991         8.845756         7.617
# 2000  1.057923e+09   4.009436      442.750219         3.840991         7.624
# 2001  1.077899e+09   3.779293      450.357901         4.823966         7.653
# ...

# %%
df
# Out:
#         population  inflation  gdp_per_capita  gdp_growth_rate  unemployment  \
# 1991  8.839276e+08  13.870246      305.574056         1.056831         7.722
# 1992  9.029571e+08  11.787817      319.182473         5.482396         7.733
# 1993  9.221184e+08   6.326890      302.884806         4.750776         7.750
# 1994  9.411638e+08  10.247936      347.734215         6.658924         7.645
# 1995  9.603010e+08  10.224886      375.176005         7.574492         7.608
# 1996  9.796785e+08   8.977152      401.046755         7.549522         7.558
# 1997  9.991338e+08   7.164252      416.228116         4.049821         7.610
# 1998  1.018665e+09  13.230839      413.630864         6.184416         7.639
# 1999  1.038226e+09   4.669820      441.927991         8.845756         7.617
# 2000  1.057923e+09   4.009436      442.750219         3.840991         7.624
# 2001  1.077899e+09   3.779293      450.357901         4.823966         7.653
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 1991 to 2023
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   population                              33 non-null     float64
#  1   inflation                               33 non-null     float64
#  2   gdp_per_capita                          33 non-null     float64
#  3   gdp_growth_rate                         33 non-null     float64
#  4   unemployment                            33 non-null     float64
#  5   life_expectancy                         33 non-null     float64
#  6   trade_balance                           33 non-null     float64
#  7   personal_remittance                     33 non-null     float64
#  8   lending_interest                        33 non-null     float64
#  9   gov_debt                                33 non-null     float64
# ...

# %%
df.describe()
# Out:
#          population  inflation  gdp_per_capita  gdp_growth_rate  unemployment  \
# count  3.300000e+01  33.000000       33.000000        33.000000     33.000000
# mean   1.180339e+09   7.085595     1088.301396         6.073195      7.386848
# std    1.715800e+08   3.085591      704.074713         2.881243      0.807192
# min    8.839276e+08   3.328173      302.884806        -5.777725      4.172000
# 25%    1.038226e+09   4.297152      441.927991         4.823966      7.601000
# 50%    1.190676e+09   6.372881      992.519585         6.795383      7.631000
# 75%    1.328024e+09   9.478997     1583.998159         7.922937      7.666000
# max    1.438070e+09  13.870246     2480.792087         9.689592      7.859000
#
#        life_expectancy  trade_balance  personal_remittance  lending_interest  \
# count        33.000000      33.000000            33.000000         33.000000
# mean         65.595515      -2.430197             2.803314         11.883134
# ...

# %%
df.isnull().sum()
# Out:
# population                                0
# inflation                                 0
# gdp_per_capita                            0
# gdp_growth_rate                           0
# unemployment                              0
# life_expectancy                           0
# trade_balance                             0
# personal_remittance                       0
# lending_interest                          0
# gov_debt                                  0
# fdi_inflows                               0
# fdi_outflows                              0
# labour_force_participation                0
# external_balance_of_goods_and_services    0
# current_acc_balance                       0
# exchange_rates                            0
# fiscal_data                               0
# dtype: int64

# %%
# to keep a track of the units of each column we make a dictionary

column_units = {
    'population': 'billions',
    'inflation': '%',
    'gdp': 'USD billions',
    'unemployment': '% of labour force',
    'life_expectancy': 'years',
    'trade_balance': '% of GDP',
    'personal_remittance': 'USD billions',
    'lending_interest': '%',
    'gov_debt': '% of GDP',
    'fdi_inflows': 'USD billions',
    'fdi_outflows': 'USD billions',
    'labour_force_participation': '% of working age population',
    'external_balance_of_goods_and_services': '% of GDP',
    'current_account_balance': '% of GDP',
    'exchange_rates': '1 dollar to rupees',
    'fiscal_data': '% of GDP'
}

# %%
df.insert(0, 'year', df.index)

# %%
df
# Out:
#       year    population  inflation  gdp_per_capita  gdp_growth_rate  \
# 1991  1991  8.839276e+08  13.870246      305.574056         1.056831
# 1992  1992  9.029571e+08  11.787817      319.182473         5.482396
# 1993  1993  9.221184e+08   6.326890      302.884806         4.750776
# 1994  1994  9.411638e+08  10.247936      347.734215         6.658924
# 1995  1995  9.603010e+08  10.224886      375.176005         7.574492
# 1996  1996  9.796785e+08   8.977152      401.046755         7.549522
# 1997  1997  9.991338e+08   7.164252      416.228116         4.049821
# 1998  1998  1.018665e+09  13.230839      413.630864         6.184416
# 1999  1999  1.038226e+09   4.669820      441.927991         8.845756
# 2000  2000  1.057923e+09   4.009436      442.750219         3.840991
# 2001  2001  1.077899e+09   3.779293      450.357901         4.823966
# 2002  2002  1.097600e+09   4.297152      469.149929         3.803975
# 2003  2003  1.116803e+09   3.805859      544.143134         7.860381
# ...

# %%
df.reset_index(inplace = True, drop = True)

# %%
df
# Out:
#     year    population  inflation  gdp_per_capita  gdp_growth_rate  \
# 0   1991  8.839276e+08  13.870246      305.574056         1.056831
# 1   1992  9.029571e+08  11.787817      319.182473         5.482396
# 2   1993  9.221184e+08   6.326890      302.884806         4.750776
# 3   1994  9.411638e+08  10.247936      347.734215         6.658924
# 4   1995  9.603010e+08  10.224886      375.176005         7.574492
# 5   1996  9.796785e+08   8.977152      401.046755         7.549522
# 6   1997  9.991338e+08   7.164252      416.228116         4.049821
# 7   1998  1.018665e+09  13.230839      413.630864         6.184416
# 8   1999  1.038226e+09   4.669820      441.927991         8.845756
# 9   2000  1.057923e+09   4.009436      442.750219         3.840991
# 10  2001  1.077899e+09   3.779293      450.357901         4.823966
# 11  2002  1.097600e+09   4.297152      469.149929         3.803975
# 12  2003  1.116803e+09   3.805859      544.143134         7.860381
# ...

# %%
df["year"] = df["year"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   year                                    33 non-null     int64
#  1   population                              33 non-null     float64
#  2   inflation                               33 non-null     float64
#  3   gdp_per_capita                          33 non-null     float64
#  4   gdp_growth_rate                         33 non-null     float64
#  5   unemployment                            33 non-null     float64
#  6   life_expectancy                         33 non-null     float64
#  7   trade_balance                           33 non-null     float64
#  8   personal_remittance                     33 non-null     float64
#  9   lending_interest                        33 non-null     float64
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
for col in df.columns.tolist():
    if col != "year":
        plt.figure(figsize = (15,8))
        sns.lineplot(x = "year", y = col, data = df, marker = "*")
        plt.xticks(ticks=df['year'], labels=df['year'], rotation=45)
        plt.minorticks_off()
        plt.title(f"{col} per year")
        plt.show()

# %% [markdown]
# ## Inflation
# - Inflation shows a **cyclic** trend.
# - Significant peaks occured in
#     - **1991**: The Indian Economic crisis and India was still recovering from The great inflation 1965 to 1982.
#     - **1998**: due to a sharp increase in the prices of agricultural products.
#     - **2009** and **2013** : due to the great depression which caused a spike in international oil prices and rise in prices of primary commodities.
#     - **2020** and **2022**: due to COVID-19 pandemic.
# - Significant dips occuring in
#     - **1993**: India recovering from The great inflation with decreasing prices of primary commodities.
#     - **1999 to 2005**: Due to abundant agricultural harvest and increased import competition.
#     - **2011**: Due to decrease in international crude oil prices and primary commodities.
#     - **2015**: Decrease in prices of manufactured products due to the Launch of **Make in India** campaign.
#     - **2017**: Introduction of Goods and Service Tax (GST)
#     - **2021**: Post pandemic there wa a focus on improving supply chain efficiency and the government also released buffer stocks to relieve the prices.
#     - **2023**: Drop in energy and commodity prices.
#
# ## GDP Per Capita
# - Per Capita GDP shows a **moderate upwards** trend from 1991 to 2002 and a **linear** trend from 2003 to 2023.
# - The spike from 2003 was influenced by increased private investment, rising savings, and substantial foreign capital inflows.
# - India experienced a slight dip in 2020 due to COVID-19 pandemic
#
# ## GDP Growth Rate
# - GDP growth rate also follows a **cyclic** trend with a drastic dip in 2020.
# - spike in growth rate occured in
#     - **1996**: due to recovery in agricultural and industrial sectors.
#     - **1999**: due to strong performance across several key sectors, including manufacturing, electricity, gas & water supply, etc. that were fueled by agricultural recovery.
#     - **2003 to 2007**: was fueled by a capital expenditure (capex) boom.
#     - **2010**: due to strong growth in the services sector.
#     - **2016**: strong domestic demand and consistent government spending.
#     - **2021**: due to government policies like "Make in India" and "Production Linked Incentive (PLI)" scheme and increased foreign direct investment.
# - Dips in growth rate occured in
#     - **1997**: the Asian financial crisis.
#     - **2000 to 2003**: due to the Asian financial crisis, a drought, the Pay Commission award, the IT bust, and the global recession of 2001.
#     - **2008**: The great Recession.
#     - **2011**: Weak manufacturing activity, rising costs and higher than bugdeted expenditure.
#     - **2020**: COVID-19 pandemic.
#
# ## Unemployment
# - Unemplyoment has a relatively stable trend over the years 1991 to 2018.
# - In 2018, the labour force participation increased and the govenment also implemented various schemes like Pradhan Mantri Kaushal Vikas Yojana (PMKVY), Craftsmen Training Scheme at ITIs, and PM Vishwakarma to promote decrease in unemployment.
# - In 2020, due to the pandemic there was a rise in unemplyment, but India recovered and unemployment continued to decrease from 2021.
#
# ## Life Expectancy
# - Life expectancy mostly followed a linear trend, except for a decrease in 2020 due to COVID-19 pandemic.
#
# ## Government Debt
# - Government debt significantly increased during
#     - The Indian economic crisis(1991)
#     - energy crisis (2003 - 2009)
#     - the COVID-19 recession.

# %% [markdown]
# # BIVARIATE ANALYSIS
# ### Development vs Growth

# %%
# GPD vs Population - To analyze productivity trends
plt.figure(figsize = (15, 6))
plt.subplot(1, 3, 1)
sns.regplot(x = df["gdp_per_capita"], y = df["population"])

# GDP vs Life Expectancy - Economic health vs social well being
plt.subplot(1, 3, 2)
sns.regplot(x = df["gdp_per_capita"], y = df["life_expectancy"])

# GDP vs Labout Force Participation - Output based on workforce size
plt.subplot(1, 3, 3)
sns.regplot(x = df["gdp_per_capita"], y = df["labour_force_participation"])
plt.show()

# %% [markdown]
# - Life Excpectancy vs gdp per capita and Population vs Gdp per capita have a positive correlation which means with growing population gdp and life expectancy also grows.
# - On the other hand, with the rise in labour force participation the gdp decreases for India.

# %% [markdown]
# ### Investment And Capital Flow

# %%
# FDI Inflows vs GDP - Foreign investment's impact on economy
plt.figure(figsize = (15, 6))
plt.subplot(1, 3, 1)
sns.regplot(x = df["gdp_per_capita"], y = df["fdi_inflows"])

# FDI Outflows vs GDP - Outbound investment and growth
plt.subplot(1, 3, 2)
sns.regplot(x = df["gdp_per_capita"], y = df["fdi_outflows"])

# FDI Inflows vs Exchange Rate - Role of currency stability
plt.subplot(1, 3, 3)
sns.regplot(x = df["fdi_inflows"], y = df["exchange_rates"])
plt.show()

# %% [markdown]
# - India has increasing foreign direct investment inflows and outflows with the increase in GDP which helps the growth of long-term inverstments.
# - However, the increasing foreign direct investments affect the conversion rate from INR to USD, reducing the INR currency value in the international market.

# %% [markdown]
# ### Fiscal & Monetary Dynamics

# %%
# Gov Debt vs GDP - Debt sustainability
plt.figure(figsize = (15, 6))
plt.subplot(1, 3, 1)
sns.regplot(x = df["gdp_per_capita"], y = df["gov_debt"])

# Gov Debt vs Lending Interest Rate - Debt pressure on rates
plt.subplot(1, 3, 2)
sns.regplot(x = df["lending_interest"], y = df["gov_debt"])

# Fiscal Data vs Inflation - Fiscal policy influence on prices
plt.subplot(1, 3, 3)
sns.regplot(x = df["fiscal_data"], y = df["inflation"])
plt.show()

# %% [markdown]
# - the governmet debt shows high volatitly, which shows significant spikes at times of crisis.
# - inlfation has a high dispersion and has a slight positive relation with fiscal data however it is not enough to derive any insights.

# %% [markdown]
# ### External Sector Health

# %%
# Trade Balance vs Exchange Rate - Currency depreciation and net exports
plt.figure(figsize = (15, 6))
plt.subplot(1, 3, 1)
sns.regplot(x = df["trade_balance"], y = df["exchange_rates"])

# External Balance vs GDP growth rate - Exports/imports and growth link
plt.subplot(1, 3, 2)
sns.regplot(x = df["external_balance_of_goods_and_services"], y = df["gdp_growth_rate"])

# Personal Remittance vs Exchange Rate - Currency's effect on remittance
plt.subplot(1, 3, 3)
sns.regplot(x = df["personal_remittance"], y = df["exchange_rates"])
plt.show()

# %% [markdown]
# - external balance of goods and service is slightly negatively correlated to the gdp growth rate of the country.
# - exchange rates have a linear relationship with personal remittance, that means the higher the currency exchange rate the more profit India will make gettting USD back to INR.

# %% [markdown]
# ## Empirical And Theoretical Models

# %% [markdown]
# ## Okun's law

# %%
for i in range(1, 25, 5):
    sns.regplot(x=df["unemployment"][i:i+5], y=df["gdp_growth_rate"][i:i+5])
    plt.title("Okun's Law: Unemployment vs GDP Growth")
    plt.show()

# %% [markdown]
# ### Okun's law states that growth rate and unemployment rate have a high negative correlation i.e. When unemployment falls, GDP tends to rise — and vice versa.
# - For India's case the validity of okun's law goes as follows:
#     - 1991-1996: negative correlation (follows)
#     - 1997-2002: near to no correlation (does not follow)
#     - 2003-2008: negative correlation (follows)
#     - 2009-2014: near to no correlation (does not follow)
#     - 2015-2020: negative correlation (follows)
#
# Hence we conclude that Okun's Law is only partially valid for Indian economical trends.

# %% [markdown]
# ## Phillips Curve

# %%
for i in range(1, 25, 5):
    sns.regplot(x=df["unemployment"][i:i+5], y=df["inflation"][i:i+5], scatter = True, scatter_kws={"s": 50})
    plt.title("Phillips curve")
    plt.show()

# %% [markdown]
# ### The Phillips curve states that inflation and unemployment have an inverse relationship; higher inflation is associated with lower unemployment and vice versa.
#
# - For India's case the validity of Phillips Curve goes as follows:
#     - 1991-1996: weak negative correlation (follows)
#     - 1997-2002: weak positive correlation (does not follow)
#     - 2003-2008: weak negative correlation (follows)
#     - 2009-2014: positive correlation (does not follow)
#     - 2015-2020: positive correlation (does not follow)
#
# Hence we conclude that Phillips Curve is only weakly and inconsistently valid for Indian economical trends.

# %% [markdown]
# ## Aggregate Supply

# %%
# SHORT RUN AGGREGATE SUPPLY (SRAS)
for i in range(1, 25, 5):
    sns.regplot(y=df["inflation"][i:i+5], x=df["gdp_per_capita"][i:i+5], scatter = True, scatter_kws={"s": 50})
    plt.title("Aggregate Supply")
    plt.show()

# %%
# LONG RUN AGGREGATE SUPPLY (LRAS)
sns.regplot(x=df["inflation"], y=df["gdp_per_capita"], scatter = True)
plt.show()

# %% [markdown]
# ### Aggregate supply is the total amount of goods and services produced at a specific price point for a particular period.
# ### GDP and inflation are usually positively correlated.
# ### In Short-term
# - 1991-1996: slight positive correlation (follows)
# - 1997-2002: negative correlation (does not follow)
# - 2003-2008: positive (follows)
# - 2009-2014: slight positive correlation (follows)
# - 2015-2020: negative correlation (does not follow)
#
# ### Long-term
# - slight negative correlation
#
# In conclusion, Aggregate supply curve is weakly valid for short term but not valid for long term.

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %%
plt.figure(figsize = (15, 10))
sns.heatmap(data = df.corr(), annot = True, cmap = "coolwarm")
plt.show()

# %% [markdown]
# ### Strong Positive Correlations (r ≥ 0.7):
# - year - gdp_per_capita: 0.97
# - year - life_expectancy: 0.98
# - gdp_per_capita - life_expectancy: 0.94
# - gdp_per_capita - exchange_rates: 0.93
# - gdp_per_capita - fiscal_data: 0.93
# - fdi_inflows - fdi_outflows: 0.81
# - life_expectancy - personal_remittance: 0.72
#
# ### Strong Negative Correlations (r ≤ -0.7):
# - year - lending_interest: -0.89
# - year - labour_force_participation: -0.80
# - gdp_per_capita - labour_force_participation: -0.86
# - life_expectancy - lending_interest: -0.88
# - exchange_rates - lending_interest: -0.85
# - gdp_per_capita - lending_interest: -0.79
# - personal_remittance - lending_interest: -0.73
#
# ### Moderate Positive Correlations (0.5 ≤ r < 0.7):
# - year - personal_remittance: 0.69
# - gdp_per_capita - fdi_inflows: 0.52
# - personal_remittance - exchange_rates: 0.59
#
# ### Moderate Negative Correlations (-0.7 < r ≤ -0.5):
# - year - unemployment: -0.52
# - year - trade_balance: -0.50
# - year - external_balance_of_goods_and_services: -0.50
# - population - lending_interest: -0.90
# - inflation - lending_interest: -0.50
# - life_expectancy - trade_balance: -0.54
# - life_expectancy - labour_force_participation: -0.79
# - personal_remittance - external_balance_of_goods_and_services: -0.68
